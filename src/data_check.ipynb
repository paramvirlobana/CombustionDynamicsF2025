# %%
import pandas as pd
import cantera as ct

# %%
df = pd.read_csv('test_data.csv')

df['PressureDropPercent'] = (df['DP_total'] / (24*ct.one_atm)) * 100

# round the column to 2 decimal place
df['PressureDropPercent'] = df['PressureDropPercent'].round(2)
df
# Out:
#        U0   PHI    xM         T_ad  m_dot_air         D  L_actual       S_L  \
# 0    60.0  0.47  20.0  1793.265891   3.357281  0.124357     0.060  0.088686
# 1    60.0  0.47  22.0  1793.265891   3.357281  0.124357     0.066  0.088686
# 2    60.0  0.47  24.0  1793.265891   3.357281  0.124357     0.072  0.088686
# 3    60.0  0.47  26.0  1793.265891   3.357281  0.124357     0.078  0.088686
# 4    70.0  0.47  20.0  1793.265891   3.357281  0.115132     0.060  0.088605
# ..    ...   ...   ...          ...        ...       ...       ...       ...
# 71  230.0  0.47  26.0  1793.265891   3.357281  0.063516     0.078  0.088563
# 72  240.0  0.47  20.0  1793.265891   3.357281  0.062178     0.060  0.088514
# 73  240.0  0.47  22.0  1793.265891   3.357281  0.062178     0.066  0.088514
# 74  240.0  0.47  24.0  1793.265891   3.357281  0.062178     0.072  0.088514
# 75  240.0  0.47  26.0  1793.265891   3.357281  0.062178     0.078  0.088514
#
# ...
