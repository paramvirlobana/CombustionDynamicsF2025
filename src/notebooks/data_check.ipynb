# %%
import pandas as pd
from inputs import *
from modules.borghi import BorghiPlot
df = pd.read_csv(os.path.join(DIR, "test_data.csv"))

# %%
# Filter rows based on column: 'U0'
df = df[df['U0'] == 90]
df = df[df['dP_percent'] < 1.2]
dff = df[df['L_premixer'] < 0.15]
dff
# Out:
#         Stabilization    U0   PHI      M    BR         T_ad  m_dot_air  \
# 63          Jet Flame  90.0  0.46  0.003   NaN  1774.452763   2.572699
# 64          Jet Flame  90.0  0.46  0.004   NaN  1774.452763   2.572699
# 65          Jet Flame  90.0  0.46  0.005   NaN  1774.452763   2.572699
# 70          Jet Flame  90.0  0.47  0.003   NaN  1793.265891   2.517961
# 71          Jet Flame  90.0  0.47  0.004   NaN  1793.265891   2.517961
# 72          Jet Flame  90.0  0.47  0.005   NaN  1793.265891   2.517961
# 77          Jet Flame  90.0  0.48  0.003   NaN  1811.951142   2.465503
# 78          Jet Flame  90.0  0.48  0.004   NaN  1811.951142   2.465503
# 79          Jet Flame  90.0  0.48  0.005   NaN  1811.951142   2.465503
# 735  Bluff Body Flame  90.0  0.46  0.003  0.01  1774.452763   2.572699
# 745  Bluff Body Flame  90.0  0.46  0.004  0.01  1774.452763   2.572699
# 755  Bluff Body Flame  90.0  0.46  0.005  0.01  1774.452763   2.572699
# ...

# %%
BorghiPlot(dff, xScatter="lt_Lf", yScatter="ui_SL")
